# %%
from functions.data_loading import *
from functions.dependency import *
from functions.genetic_embedding import *
from functions.visualization import *
from functions.exporter import *

# %%
netscience_net = load_net_from_edge_list(path='datasets/ca-netscience_edges.csv', sep=' ', has_edge_weights = False)

# %%
dep_matrix = dependency_matrix(netscience_net)

# %%
len(dep_matrix)
# Out:
# 379

# %% [markdown]
# # GeneticEmbeddingV1

# %%
genetic_embedding = GeneticEmbeddingV1(network=netscience_net, dependency_matrix=dep_matrix, embedding_dim=2)
embs_v1 = genetic_embedding.run(iterations=1000)

# %%
visualize_network(netscience_net, embs_v1)

# %% [markdown]
# # GeneticEmbeddingV2

# %%
genetic_embedding = GeneticEmbeddingV2(network=netscience_net, dependency_matrix=dep_matrix, embedding_dim=2)
embs_v2 = genetic_embedding.run(iterations=1000)

# %%
visualize_network(netscience_net, embs_v2)

# %% [markdown]
# # GeneticEmbeddingV3

# %%
genetic_embedding = GeneticEmbeddingV3(network=netscience_net, dependency_matrix=dep_matrix, embedding_dim=2, max_step_portion=0.1)
embs_v3 = genetic_embedding.run(iterations=2000)

# %%
visualize_network(netscience_net, embs_v3)

# %%
export_to_gdf("netscience2.gdf",netscience_net,embs_v3,False)

# %% [markdown]
# # GeneticEmbeddingAbsLog

# %%
from

# %%
genetic_embedding = GeneticEmbeddingAbsLog(network=netscience_net, dependency_matrix=dep_matrix, embedding_dim=10, max_step_portion=0.1)
embs_v3 = genetic_embedding.run(iterations=2000)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)

# %%
embs = pca.fit_transform(embs_v3)

# %%
visualize_network(netscience_net, embs)

# %%
export_to_gdf("netscience10PCA2.gdf",netscience_net,embs,False)
